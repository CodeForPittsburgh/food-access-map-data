# %% [markdown]
# # Dataset ingestion script prototype
#
# This notebook is intended to prototype code snippets for an ingestion script aimed at "Summer_Meal_Sites_2019.csv".
#
# Dependencies:
# * pandas
# * os

# %%
import pandas as pd
import os

# %%
in_path = '../food-data/PFPC_data_files/Summer_Meal_Sites_2019.csv'
out_path = '../food-data/Cleaned_data_files/summer_meal_sites_2019.csv'

final_cols = ['id', 'source_org', 'source_file', 'original_id', 'type', 'name', 'address', 'city', 
              'state', 'zip_code', 'county', 'location_description', 'phone', 'url', 'latitude', 
              'longitude', 'latlng_source', 'date_from', 'date_to', 'SNAP', 'WIC', 'FMNP', 
              'fresh_produce', 'food_bucks', 'free_distribution', 'open_to_spec_group', 'data_issues']

# %%
df = pd.read_csv(in_path, encoding = 'ansi')
df
# Out:
# C:\Miniconda3\envs\data-science\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                X          Y  OBJECTID                     siteName siteStatus  \
# 0     -79.095379  34.480939     49094                Fairmont High       Open
# 1     -79.031752  34.603793     49095        Lumberton Junior High       Open
# 2     -79.003666  34.712291     49096          Magnolia Elementary       Open
# 3     -79.194384  34.676639     49097          Pembroke Elementary       Open
# 4     -79.232282  34.733090     49098          Prospect Elementary       Open
# ...          ...        ...       ...                          ...        ...
# 57583 -98.504059  29.433697    140165              BARKLEY/RUIZ EL       Open
# 57584 -97.484003  32.665264    140166  BENBROOK MIDDLE/HIGH SCHOOL       Open
# 57585 -93.888960  30.672447    140167   Bleakwood Community Center       Open
# 57586 -93.927672  29.928196    140168               Brittany Place       Open
# 57587 -97.691791  31.130820    140169                BROOKHAVEN EL       Open
#
#                                       siteAddress siteAddress2     siteCity  \
# 0          5419 Old Stage Roae Fairmont, NC 28340          NaN     Fairmont
# 1              82 Marion Road Lumberton, NC 28358          NaN    Lumberton
# 2          10928 US 301 North Lumberton, NC 28360          NaN    Lumberton
# 3       505 SOUTH JONES STREET PEMBROKE, NC 28372          NaN     PEMBROKE
# 4           4024 MISSOURI ROAD PEMBROKE, NC 28372          NaN     PEMBROKE
# ...                                           ...          ...          ...
# 57583  2 Haven for Hope Way San Antonio, TX 78207          NaN  San Antonio
# 57584            201 Overcrest Benbrook, TX 76126          NaN     Benbrook
# 57585             266 FM 363 Kirbyville, TX 75956          NaN   Kirbyville
# 57586   3500 Normandy Place Port Arthur, TX 77642          NaN  Port Arthur
# 57587          3221 Hilliard Rd Killeen, TX 76543          NaN      Killeen
#
#       siteState siteZip  ...  snackTimePM  dinnerSupperTime mealTypesServed  \
# 0            NC   28340  ...          NaN               NaN             B,L
# 1            NC   28358  ...          NaN               NaN             B,L
# 2            NC   28360  ...          NaN               NaN             B,L
# 3            NC   28372  ...          NaN               NaN             B,L
# 4            NC   28372  ...          NaN               NaN             B,L
# ...         ...     ...  ...          ...               ...             ...
# 57583        TX   78207  ...          NaN               NaN             NaN
# 57584        TX   76126  ...          NaN               NaN             NaN
# 57585        TX   75956  ...          NaN               NaN             NaN
# 57586        TX   77642  ...          NaN               NaN             NaN
# 57587        TX   76543  ...          NaN               NaN             NaN
#
#       cycleNumber  RecordStatus Country   FNSID Created Season     County
# 0               2             N      US   75727     NaN   2019    Robeson
# 1               2             N      US   16116     NaN   2019    Robeson
# 2               2             N      US   16134     NaN   2019    Robeson
# 3               2             N      US   16405     NaN   2019    Robeson
# 4               2             N      US   76614     NaN   2019    Robeson
# ...           ...           ...     ...     ...     ...    ...        ...
# 57583          11             U      US  132450     NaN   2019      Bexar
# 57584          11             U      US   25834     NaN   2019    Tarrant
# 57585          11             U      US  120536     NaN   2019     Jasper
# 57586          11             U      US    3497     NaN   2019  Jefferson
# 57587          11             U      US  106277     NaN   2019       Bell
#
# [57588 rows x 33 columns]

# %%
# Filter down to Allegheny County sites only
df = df.loc[(df['siteState'] == 'PA') & (df['County'] == 'Allegheny')]

# Assign some columns to schema fields
df['original_id'] = df['FNSID']
df['name'] = df['siteName'].str.title() # deal with ALL CAPS
df['city'] = df['siteCity'].str.title()
df['state'] = df['siteState']
df['zip_code'] = df['siteZip'].str.zfill(5)
df['county'] = df['County']
df['latitude'] = df['Y']
df['longitude'] = df['X']

# Handle phone numbers with and without extensions
df.loc[df['ext'].notnull(), 'phone'] = df.loc[df['ext'].notnull(), 'sitePhone'].astype('int64').astype(str) + \
                                       'x' + df.loc[df['ext'].notnull(), 'ext'].astype('int64').astype(str)
df.loc[df['ext'].isnull(), 'phone'] = df.loc[df['ext'].isnull(), 'sitePhone']

# Handle address, fun text processing
df['address'] = df.apply(lambda x: x['siteAddress'].split(' ' + x['siteCity'])[0].title(), axis = 1)

# Set some fields directly
df['source_org'] = 'USDA Food and Nutrition Service'
df['source_file'] = os.path.basename(in_path)
df['type'] = "summer meal site"
df['latlng_source'] = df['source_org']

df['SNAP'] = 0
df['WIC'] = 0
df['FMNP'] = 0
# df['fresh_produce'] = 1
df['food_bucks'] = 0
df['free_distribution'] = 1
df['open_to_spec_group'] = 'children and teens 18 and younger'
df['data_issues'] = '' # start with blank field, to populate later

# Calculate date_from and date_to
df['date_from'] = df['startDate'].str.split('T').str[0]
df['date_to'] = df['endDate'].str.split('T').str[0]

# Reorder and add any missing columns
df = df.reindex(columns = final_cols)

# Identify which columns we have handled
handled_cols = df.columns[~df.isna().all()] # i.e. columns that aren't all NA

# Detect and document missingness in handled columns
for col in handled_cols:
    df.loc[df[col].isna(), 'data_issues'] += '{} missing;'.format(col)

# Detect some specific data issues 
df.loc[((df['latitude'] == 0) & (df['longitude'] == 0)), 'data_issues'] += 'latlng is (0,0);'

# Write out to CSV
df.to_csv(out_path, index = False)

df
# Out:
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Miniconda3\envs\data-science\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Miniconda3\envs\data-science\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        id                       source_org                 source_file  \
# 1555  NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 2253  NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 2254  NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 2255  NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 2259  NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# ...    ..                              ...                         ...
# 57459 NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 57460 NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 57469 NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 57470 NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
# 57483 NaN  USDA Food and Nutrition Service  Summer_Meal_Sites_2019.csv
#
#        original_id              type                              name  \
# 1555          4808  summer meal site      Hillel Academy Of Pittsburgh
# 2253         41960  summer meal site            Castle Shannon Library
# 2254         40957  summer meal site                    Alvern Gardens
# 2255         43679  summer meal site            Green Tree Wilson Park
# 2259         42688  summer meal site  Dormont Park / Pool & Rec Center
# ...            ...               ...                               ...
# 57459        84713  summer meal site                    Allegheny Ymca
# 57460        92916  summer meal site     Burgwin Spray Park/Playground
# 57469       149550  summer meal site                      Yp Northview
# 57470       104548  summer meal site                      Mount Ararat
# 57483        85959  summer meal site                       Evo Pacific
#
#                                 address        city state zip_code  ...  \
# 1555                 5685 Beacon Street  Pittsburgh    PA    15217  ...
# 2253                 3677 Myrtle Avenue         Pgh    PA    15234  ...
# 2254                   1000 Vermont Ave  Pittsburgh    PA    15234  ...
# 2255                 10 West Manilla Dr         Pgh    PA    15220  ...
# 2259                   1801 Dormont Ave         Pgh    PA    15216  ...
# ...                                 ...         ...   ...      ...  ...
# 57459               600 W. North Avenue  Pittsburgh    PA      NaN  ...
# 57460  Johnston Avenue @ Mansion Street  Pittsburgh    PA      NaN  ...
# 57469             525 Mt. Pleasant Road  Pittsburgh    PA      NaN  ...
# 57470              745 N. Negley Avenue  Pittsburgh    PA      NaN  ...
# 57483                 250 S Pacific Ave  Pittsburgh    PA      NaN  ...
#
#         date_from     date_to SNAP  WIC  FMNP  fresh_produce food_bucks  \
# 1555   2019-06-24  2019-08-02    0    0     0            NaN          0
# 2253   2019-06-10  2019-08-16    0    0     0            NaN          0
# 2254   2019-06-10  2019-08-16    0    0     0            NaN          0
# 2255   2019-06-10  2019-08-16    0    0     0            NaN          0
# 2259   2019-06-10  2019-08-16    0    0     0            NaN          0
# ...           ...         ...  ...  ...   ...            ...        ...
# 57459  2019-06-17  2019-08-23    0    0     0            NaN          0
# 57460  2019-06-26  2019-08-23    0    0     0            NaN          0
# 57469  2019-06-24  2019-08-02    0    0     0            NaN          0
# 57470  2019-06-24  2019-08-16    0    0     0            NaN          0
# 57483  2019-06-17  2019-08-16    0    0     0            NaN          0
#
#       free_distribution                 open_to_spec_group        data_issues
# 1555                  1  children and teens 18 and younger
# 2253                  1  children and teens 18 and younger
# 2254                  1  children and teens 18 and younger
# 2255                  1  children and teens 18 and younger
# 2259                  1  children and teens 18 and younger
# ...                 ...                                ...                ...
# 57459                 1  children and teens 18 and younger  zip_code missing;
# 57460                 1  children and teens 18 and younger  zip_code missing;
# 57469                 1  children and teens 18 and younger  zip_code missing;
# 57470                 1  children and teens 18 and younger  zip_code missing;
# 57483                 1  children and teens 18 and younger  zip_code missing;
#
# [285 rows x 27 columns]
