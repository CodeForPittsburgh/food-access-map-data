# %% [markdown]
# # Fresh Corners ingestion script prototype
#
# This notebook is intended to prototype code snippets for an ingestion script aimed at "Just Harvest - Fresh Corners Stores.xlsx".
#
# Dependencies:
# * pandas
# * xlrd
# * os

# %%
import pandas as pd
import os

# %%
in_path = '../food-data/PFPC_data_files/Just Harvest - Fresh Corners Stores.xlsx'
out_path = '../food-data/Cleaned_data_files/just_harvest_fresh_corners.csv'

final_cols = ['id', 'source_org', 'source_file', 'original_id', 'type', 'name', 'address', 'city', 
              'state', 'zip_code', 'county', 'location_description', 'phone', 'url', 'latitude', 
              'longitude', 'latlng_source', 'date_from', 'date_to', 'SNAP', 'WIC', 'FMNP', 
              'fresh_produce', 'food_bucks', 'free_distribution', 'open_to_spec_group', 'data_issues']

# %%
df = pd.read_excel(in_path)
df
# Out:
#              Area            Corner Store               Address          City  \
# 0         Carrick            Juba Grocery   2721 Brownsville Rd    Pittsburgh
# 1          Rankin             Carl's Café           337 5th Ave        Rankin
# 2    East Liberty        Farm Fresh Foods     226 N. Negley Ave    Pittsburgh
# 3         Larimer            L.A. Grocery       511 Larimer Ave    Pittsburgh
# 4      McKeesport        Bailey Food Mart       2316 Bailie Ave    McKeesport
# 5    McKees Rocks  In & Out Corner Market         300 Helen St.  McKees Rocks
# 6    McKees Rocks           Rocks Express  700 Frederick Street  McKees Rocks
# 7      Mt. Oliver        Deann's Groceria   207 Brownsville Rd.  Mount Oliver
# 8          Uptown       \nSchwartz Market          1901 5th Ave    Pittsburgh
# 9        Clairton     Produce Marketplace      519 St Clair Ave      Clairton
# 10  Hill District            Ann's Market      2316 Webster Ave    Pittsburgh
#
#       Zip  Notes Participates in Food Bucks SNAP Incentive Program
# 0   15227    NaN                                               NaN
# 1   15104    NaN                                               yes
# 2   15206    NaN                                               NaN
# 3   15206    NaN                                               NaN
# 4   15132    NaN                                               NaN
# 5   15136    NaN                                               yes
# 6   15136    NaN                                               yes
# 7   15210    NaN                                               NaN
# 8   15219    NaN                                               NaN
# 9   15025    NaN                                               yes
# 10  15219    NaN                                               NaN

# %%
# Assign some columns to schema fields
df['name'] = df['Corner Store'].str.strip('\n')
df['address'] = df['Address']
df['city'] = df['City']
df['zip_code'] = df['Zip']

# Set some fields directly
df['source_org'] = 'Just Harvest'
df['source_file'] = os.path.basename(in_path)
df['type'] = "convenience store" # debatable!
df['state'] = 'PA'
df['county'] = 'Allegheny'
df['FMNP'] = 1 # per rules from Cat
df['fresh_produce'] = 1 # the whole point of the program
df['food_bucks'] = 0 # start with 0 and set relevant sites to 1
df.loc[df['Participates in Food Bucks SNAP Incentive Program'] == 'yes', 'food_bucks'] = 1
df.loc[df['food_bucks'] == 1, 'SNAP'] = 1
df['free_distribution'] = 0
df['data_issues'] = '' # start with blank field, to populate later

# Reorder and add any missing columns
df = df.reindex(columns = final_cols)

# Identify which columns we have handled
handled_cols = df.columns[~df.isna().all()] # i.e. columns that aren't all NA

# Detect and document missingness in handled columns
for col in handled_cols:
    df.loc[df[col].isna(), 'data_issues'] += '{} missing;'.format(col)

# Write out to CSV
df.to_csv(out_path, index = False)

df
# Out:
#     id    source_org                               source_file  original_id  \
# 0  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 1  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 2  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 3  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 4  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 5  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 6  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 7  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 8  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 9  NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
# 10 NaN  Just Harvest  Just Harvest - Fresh Corners Stores.xlsx          NaN
#
#                  type                    name               address  \
# 0   convenience store            Juba Grocery   2721 Brownsville Rd
# 1   convenience store             Carl's Café           337 5th Ave
# 2   convenience store        Farm Fresh Foods     226 N. Negley Ave
# 3   convenience store            L.A. Grocery       511 Larimer Ave
# 4   convenience store        Bailey Food Mart       2316 Bailie Ave
# 5   convenience store  In & Out Corner Market         300 Helen St.
# 6   convenience store           Rocks Express  700 Frederick Street
# 7   convenience store        Deann's Groceria   207 Brownsville Rd.
# 8   convenience store         Schwartz Market          1901 5th Ave
# 9   convenience store     Produce Marketplace      519 St Clair Ave
# 10  convenience store            Ann's Market      2316 Webster Ave
#
#             city state  zip_code  ... date_from  date_to  SNAP  WIC  FMNP  \
# 0     Pittsburgh    PA     15227  ...       NaN      NaN   NaN  NaN     1
# 1         Rankin    PA     15104  ...       NaN      NaN   1.0  NaN     1
# 2     Pittsburgh    PA     15206  ...       NaN      NaN   NaN  NaN     1
# 3     Pittsburgh    PA     15206  ...       NaN      NaN   NaN  NaN     1
# 4     McKeesport    PA     15132  ...       NaN      NaN   NaN  NaN     1
# 5   McKees Rocks    PA     15136  ...       NaN      NaN   1.0  NaN     1
# 6   McKees Rocks    PA     15136  ...       NaN      NaN   1.0  NaN     1
# 7   Mount Oliver    PA     15210  ...       NaN      NaN   NaN  NaN     1
# 8     Pittsburgh    PA     15219  ...       NaN      NaN   NaN  NaN     1
# 9       Clairton    PA     15025  ...       NaN      NaN   1.0  NaN     1
# 10    Pittsburgh    PA     15219  ...       NaN      NaN   NaN  NaN     1
#
#     fresh_produce  food_bucks  free_distribution  open_to_spec_group  \
# 0               1           0                  0                 NaN
# 1               1           1                  0                 NaN
# 2               1           0                  0                 NaN
# 3               1           0                  0                 NaN
# 4               1           0                  0                 NaN
# 5               1           1                  0                 NaN
# 6               1           1                  0                 NaN
# 7               1           0                  0                 NaN
# 8               1           0                  0                 NaN
# 9               1           1                  0                 NaN
# 10              1           0                  0                 NaN
#
#       data_issues
# 0   SNAP missing;
# 1
# 2   SNAP missing;
# 3   SNAP missing;
# 4   SNAP missing;
# 5
# 6
# 7   SNAP missing;
# 8   SNAP missing;
# 9
# 10  SNAP missing;
#
# [11 rows x 27 columns]
