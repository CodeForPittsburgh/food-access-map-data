# %% [markdown]
# # Just Harvest Fresh Access Markets ingestion script prototype
#
# This notebook is intended to prototype code snippets for an ingestion script aimed at "Just Harvest - Fresh Access Markets.xlsx".
#
# Dependencies:
# * pandas
# * xlrd
# * re
# * os

# %%
import pandas as pd
import re
import os

# %%
in_path = '../food-data/PFPC_data_files/Just Harvest - Fresh Access Markets.xlsx'
out_path = '../food-data/Cleaned_data_files/just_harvest_fresh_access_markets.csv'

final_cols = ['id', 'source_org', 'source_file', 'original_id', 'type', 'name', 'address', 'city', 
              'state', 'zip_code', 'county', 'location_description', 'phone', 'url', 'latitude', 
              'longitude', 'latlng_source', 'date_from', 'date_to', 'SNAP', 'WIC', 'FMNP', 
              'fresh_produce', 'food_bucks', 'free_distribution', 'open_to_spec_group', 'data_issues']

# %%
df = pd.read_excel(in_path)
df
# Out:
#                               Market                 address  \
# 0           Beechview Farmers Market      1563 Beechview Ave
# 1           Belllevue Farmers Market          34 N Balph Ave
# 2         Bloomfield Saturday Market        5050 Liberty Ave
# 3             Carrick Farmers Market   1529 Brownsville Road
# 4        East Liberty Farmers Market                     NaN
# 5                Garfield Farm Stand                     NaN
# 6          Green Tree Farmers Market      905 Greentree Road
# 7            Homewood Farmers Market     7139 Fransktown Ave
# 8            Homewood Farmers Market     7139 Fransktown Ave
# 9             Larimer Farmers Market                     NaN
# 10      Lawrenceville Farmers Market                     NaN
# 11      Market Square Farmers Market                     NaN
# 12      Mellon Square Farmers Market                     NaN
# 13      Moon Township Farmers Market  1000 Beaver Grade Road
# 14         North Side Farmers Market                     NaN
# 15    Peters Township Farmers Market    905 East McMurray Rd
# 16         South Side Farmers Market                     NaN
# 17      Squirrel Hill Farmers Market                     NaN
# 18          Swissvale Farmers Market        7301 Schoyer Ave
# 19  Wilkinsburg Thursday Open Market         225 Penn Avenue
# 20               Braddock Farm Stand       1000 Braddock Ave
# 21                Shiloah Farm Stand                     NaN
#
#           street_one     street_two         city state  zip_code  \
# 0       Broadway Ave  Hampshire Ave          NaN    PA   15216.0
# 1                NaN            NaN     Bellevue    PA   15202.0
# 2                NaN            NaN   Pittsburgh    PA   15224.0
# 3                NaN            NaN   Pittsburgh    PA   15210.0
# 4           Broad St     Station St   Pittsburgh    PA   15206.0
# 5          Wiclow St     Columbo St   Pittsburgh    PA   15224.0
# 6                NaN            NaN   Pittsburgh    PA   15220.0
# 7                NaN            NaN   Pittsburgh    PA   15208.0
# 8                NaN            NaN   Pittsburgh    PA   15208.0
# 9        Larimer Ave      Carver St   Pittsburgh    PA       NaN
# 10           40th St      Butler St   Pittsburgh    PA   15201.0
# 11        Forbes Ave      Market St   Pittsburgh    PA   15222.0
# 12     Smithfield St      Sixth Ave   Pittsburgh    PA   15222.0
# 13               NaN            NaN         Moon    PA   15108.0
# 14      East Ohio St      Cedar Ave   Pittsburgh    PA   15101.0
# 15               NaN            NaN      Venetia    PA   15367.0
# 16           18th St      Carson St   Pittsburgh    PA   15203.0
# 17         Beacon St    Bartlett St   Pittsburgh    PA   15217.0
# 18               NaN            NaN    Swissvale    PA   15218.0
# 19               NaN            NaN  Wilkinsburg    PA   15221.0
# 20          Braddock            6th     Braddock    PA   15104.0
# 21  Thomas Boulevard       Homewood   Pittsburgh    PA   15208.0
#
#                       Season               Date/Time    weekday open_time1  \
# 0   June 20th-September 12th        Thursday 3pm-7pm   Thursday   15:00:00
# 1      June 5th-October 30th      Wednesdays 3pm-7pm  Wednesday   15:00:00
# 2      May 18th-November 2nd       Saturdays 9am-1pm   Saturday   09:00:00
# 3    June 19th-November 27th      Wednesdays 3pm-7pm  Wednesday   15:00:00
# 4     May 13th-November 25th         Mondays 3pm-7pm     Monday   15:00:00
# 5    June 5th-September 25th   Wednesdays 3pm-7:30pm  Wednesday   16:00:00
# 6      May 23rd-October 31st       Thursdays 4pm-7pm   Thursday   15:00:00
# 7     July 27th-October 26th  Last Saturdays 3pm-7pm   Saturday   15:00:00
# 8         July 3rd-July 31st    Wednedays 3pm-5:30pm  Wednesday   15:00:00
# 9    June 23rd-November 24th     4th Sundays 3pm-7pm     Sunday   16:00:00
# 10    June 4th-October 29tth        Tuesdays 4pm-7pm    Tuesday   10:00:00
# 11     May 16th-October 31st      Thursdays 10am-2pm   Thursday   10:30:00
# 12     May 10th-October 25th  Fridays 10:30am-1:30pm     Friday   15:00:00
# 13   June 5th-September 25th      Wednesdays 3pm-6pm  Wednesday   15:00:00
# 14    May 17th-November 22nd         Fridays 3pm-7pm     Friday   15:00:00
# 15   May 22nd-September 25th      Wednesdays 3pm-7pm  Wednesday   15:00:00
# 16    May 14th-November 26th        Tuesdays 3pm-7pm    Tuesday   15:00:00
# 17    May 12th-November 24th         Sundays 9am-1pm     Sunday   09:00:00
# 18     June 1st-October 26th       Saturdays 9am-1pm   Saturday   09:00:00
# 19   June 13th-November 14th     Thursdays 3pm-6p30m   Thursday   15:00:00
# 20     June 1st-October 26th       Saturdays10am-2pm   Saturday   10:00:00
# 21     June 6th-October 31sr       Thursdaus 3pm-6pm   Thursday   15:00:00
#
#    close_time1                     description  \
# 0     19:00:00                             NaN
# 1     19:00:00                      Bayne Park
# 2     13:00:00                             NaN
# 3     19:00:00                             NaN
# 4     19:00:00  Garland Parklet Lot. N. Euclid
# 5     19:00:00                             NaN
# 6     19:00:00                             NaN
# 7     17:30:00                   Last Saturday
# 8     19:00:00                             NaN
# 9     19:00:00                      4th Sunday
# 10    14:00:00                    Arsenal Park
# 11    13:30:00                             NaN
# 12    18:00:00             Mellon Square Park,
# 13    19:00:00        Moon Municipal Building,
# 14    19:00:00                             NaN
# 15    19:00:00                             NaN
# 16    19:00:00                             NaN
# 17    13:00:00                             NaN
# 18    13:00:00      Lot behind Dickson School,
# 19    18:30:00                             NaN
# 20    14:00:00                             NaN
# 21    18:00:00                             NaN
#
#    Participates in Food Bucks SNAP Incentive program
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
# 5                                                yes
# 6                                                yes
# 7                                                yes
# 8                                                yes
# 9                                                yes
# 10                                               yes
# 11                                               yes
# 12                                               yes
# 13                                               yes
# 14                                               yes
# 15                                               yes
# 16                                               yes
# 17                                               yes
# 18                                               yes
# 19                                               yes
# 20                                               yes
# 21                                               yes

# %%
# Assign some columns to schema fields
df['name'] = df['Market']
df['location_description'] = df['description']

# Set some fields directly
df['source_org'] = 'Just Harvest'
df['source_file'] = os.path.basename(in_path)
df['type'] = "farmer's market"
df['county'] = 'Allegheny'
df['SNAP'] = 1 # because of food_bucks, see below
df['WIC'] = 1 # based on inspection of http://www.justharvest.org/fresh-access/local-farmers-markets-and-farm-stands-accepting-food-stamps/
df['FMNP'] = 1 # per rules from Cat
df['fresh_produce'] = 1
df['food_bucks'] = 1
df['free_distribution'] = 0
df['data_issues'] = '' # start with blank field, to populate later

# Fill missing addresses with intersections
df.loc[df['address'].isna(), 'address'] = df.loc[df['address'].isna(), 'street_one'] \
    + ' & ' + df.loc[df['address'].isna(), 'street_two']

# Calculate date_from and date_to from Season field
df['date_from'] = df['Season'].apply(lambda x: re.search(r'.+\d', x.split('-')[0]).group())
df['date_to'] = df['Season'].apply(lambda x: re.search(r'.+\d', x.split('-')[1]).group())

# Someday we will handle opening days/times robustly. For now I will append them to location_description :P
df.loc[df['location_description'].notna(), 'location_description'] = df['location_description'] + '; ' + df['Date/Time']
df.loc[df['location_description'].isna(), 'location_description'] = df['Date/Time']

# Reorder and add any missing columns
df = df.reindex(columns = final_cols)

# Identify which columns we have handled
handled_cols = df.columns[~df.isna().all()] # i.e. columns that aren't all NA

# Detect and document missingness in handled columns
for col in handled_cols:
    df.loc[df[col].isna(), 'data_issues'] += '{} missing;'.format(col)

# Write out to CSV
df.to_csv(out_path, index = False)

df
# Out:
#     id    source_org                               source_file  original_id  \
# 0  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 1  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 2  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 3  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 4  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 5  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 6  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 7  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 8  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 9  NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 10 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 11 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 12 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 13 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 14 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 15 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 16 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 17 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 18 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 19 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 20 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
# 21 NaN  Just Harvest  Just Harvest - Fresh Access Markets.xlsx          NaN
#
#                type                              name  \
# 0   farmer's market          Beechview Farmers Market
# 1   farmer's market          Belllevue Farmers Market
# 2   farmer's market        Bloomfield Saturday Market
# 3   farmer's market            Carrick Farmers Market
# 4   farmer's market       East Liberty Farmers Market
# 5   farmer's market               Garfield Farm Stand
# 6   farmer's market         Green Tree Farmers Market
# 7   farmer's market           Homewood Farmers Market
# 8   farmer's market           Homewood Farmers Market
# 9   farmer's market            Larimer Farmers Market
# 10  farmer's market      Lawrenceville Farmers Market
# 11  farmer's market      Market Square Farmers Market
# 12  farmer's market      Mellon Square Farmers Market
# 13  farmer's market      Moon Township Farmers Market
# 14  farmer's market         North Side Farmers Market
# 15  farmer's market    Peters Township Farmers Market
# 16  farmer's market         South Side Farmers Market
# 17  farmer's market      Squirrel Hill Farmers Market
# 18  farmer's market          Swissvale Farmers Market
# 19  farmer's market  Wilkinsburg Thursday Open Market
# 20  farmer's market               Braddock Farm Stand
# 21  farmer's market                Shiloah Farm Stand
#
#                         address         city state  zip_code  ... date_from  \
# 0            1563 Beechview Ave          NaN    PA   15216.0  ...   June 20
# 1                34 N Balph Ave     Bellevue    PA   15202.0  ...    June 5
# 2              5050 Liberty Ave   Pittsburgh    PA   15224.0  ...    May 18
# 3         1529 Brownsville Road   Pittsburgh    PA   15210.0  ...   June 19
# 4         Broad St & Station St   Pittsburgh    PA   15206.0  ...    May 13
# 5        Wiclow St & Columbo St   Pittsburgh    PA   15224.0  ...    June 5
# 6            905 Greentree Road   Pittsburgh    PA   15220.0  ...    May 23
# 7           7139 Fransktown Ave   Pittsburgh    PA   15208.0  ...   July 27
# 8           7139 Fransktown Ave   Pittsburgh    PA   15208.0  ...    July 3
# 9       Larimer Ave & Carver St   Pittsburgh    PA       NaN  ...   June 23
# 10          40th St & Butler St   Pittsburgh    PA   15201.0  ...    June 4
# 11       Forbes Ave & Market St   Pittsburgh    PA   15222.0  ...    May 16
# 12    Smithfield St & Sixth Ave   Pittsburgh    PA   15222.0  ...    May 10
# 13       1000 Beaver Grade Road         Moon    PA   15108.0  ...    June 5
# 14     East Ohio St & Cedar Ave   Pittsburgh    PA   15101.0  ...    May 17
# 15         905 East McMurray Rd      Venetia    PA   15367.0  ...    May 22
# 16          18th St & Carson St   Pittsburgh    PA   15203.0  ...    May 14
# 17      Beacon St & Bartlett St   Pittsburgh    PA   15217.0  ...    May 12
# 18             7301 Schoyer Ave    Swissvale    PA   15218.0  ...    June 1
# 19              225 Penn Avenue  Wilkinsburg    PA   15221.0  ...   June 13
# 20            1000 Braddock Ave     Braddock    PA   15104.0  ...    June 1
# 21  Thomas Boulevard & Homewood   Pittsburgh    PA   15208.0  ...    June 6
#
#          date_to  SNAP  WIC  FMNP  fresh_produce  food_bucks  \
# 0   September 12     1    1     1              1           1
# 1     October 30     1    1     1              1           1
# 2     November 2     1    1     1              1           1
# 3    November 27     1    1     1              1           1
# 4    November 25     1    1     1              1           1
# 5   September 25     1    1     1              1           1
# 6     October 31     1    1     1              1           1
# 7     October 26     1    1     1              1           1
# 8        July 31     1    1     1              1           1
# 9    November 24     1    1     1              1           1
# 10    October 29     1    1     1              1           1
# 11    October 31     1    1     1              1           1
# 12    October 25     1    1     1              1           1
# 13  September 25     1    1     1              1           1
# 14   November 22     1    1     1              1           1
# 15  September 25     1    1     1              1           1
# 16   November 26     1    1     1              1           1
# 17   November 24     1    1     1              1           1
# 18    October 26     1    1     1              1           1
# 19   November 14     1    1     1              1           1
# 20    October 26     1    1     1              1           1
# 21    October 31     1    1     1              1           1
#
#    free_distribution open_to_spec_group        data_issues
# 0                  0                NaN      city missing;
# 1                  0                NaN
# 2                  0                NaN
# 3                  0                NaN
# 4                  0                NaN
# 5                  0                NaN
# 6                  0                NaN
# 7                  0                NaN
# 8                  0                NaN
# 9                  0                NaN  zip_code missing;
# 10                 0                NaN
# 11                 0                NaN
# 12                 0                NaN
# 13                 0                NaN
# 14                 0                NaN
# 15                 0                NaN
# 16                 0                NaN
# 17                 0                NaN
# 18                 0                NaN
# 19                 0                NaN
# 20                 0                NaN
# 21                 0                NaN
#
# [22 rows x 27 columns]
