# %% [markdown]
# # Dataset ingestion script prototype
#
# This notebook is intended to prototype code snippets for an ingestion script aimed at "filename".
#
# Dependencies:
# * pandas
# * os

# %%
import pandas as pd
import os

# %%
in_path = '../food-data/PFPC_data_files/input.file'
out_path = '../food-data/Cleaned_data_files/output.file'

final_cols = ['id', 'source_org', 'source_file', 'original_id', 'type', 'name', 'address', 'city', 
              'state', 'zip_code', 'county', 'location_description', 'phone', 'url', 'latitude', 
              'longitude', 'latlng_source', 'date_from', 'date_to', 'SNAP', 'WIC', 'FMNP', 
              'fresh_produce', 'food_bucks', 'free_distribution', 'open_to_spec_group', 'data_issues']

# %%
df = pd.read_csv(in_path)
df
# Out:
#                                 Name             Street_Address  \
# 0           Ambridge Farmer's Market              624 Park Road
# 1              Aspinwall Flea Market      217 Commerical Avenue
# 2   Bachman's Greenhouse and Nursery         2905 Freeport Road
# 3   Bachman's Greenhouse and Nursery  Route 908 & Ekastown Road
# 4              Beccari's Farm Market        5095 Thoms Run Road
# ..                               ...                        ...
# 87                     Wexford Farms        550 Warrendale Road
# 88  Wilkins Township Farmer's Market  333 Penn Center Boulevard
# 89       Wilkinsburg Farmer's Market            225 Penn Avenue
# 90           Wilmerding Green Grocer        314 Commerce Street
# 91            Woods Run Green Grocer      1201 Woods Run Avenue
#
#                City State    Zip   Latitude  Longitude  \
# 0          Ambridge    PA  15003  40.586729 -80.229576
# 1         Aspinwall    PA  15215  40.490575 -79.904305
# 2   Natrona Heights    PA  15065  40.640015 -79.711384
# 3   Natrona Heights    PA  15065  40.667206 -79.730284
# 4           Oakdale    PA  15071  40.373965 -80.133129
# ..              ...   ...    ...        ...        ...
# 87          Wexford    PA  15090  40.647630 -80.100129
# 88       Pittsburgh    PA  15235  40.427682 -79.811636
# 89       Pittsburgh    PA  15221  40.446769 -79.891807
# 90       Wilmerding    PA  15148  40.392927 -79.807721
# 91       Pittsburgh    PA  15212  40.476243 -80.030199
#
#                              Additional_Directions  \
# 0   St. Mary's Church parking lot, near Do It Best
# 1                            Municipal parking lot
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 87                                             NaN
# 88                            Route 22 Penn Center
# 89                  Life Care Hospital parking lot
# 90                           Wilmerding Apartments
# 91                               Woods Run Library
#
#                                              Day_Time         Season  \
# 0                            Thursday 4:00 PM-7:00 PM  June-November
# 1                              Sunday 7:00 AM-1:00 PM  June-November
# 2                               Daily 8:00 AM-7:00 PM   June-October
# 3                              Daily 10:00 AM-6:00 PM   July-October
# 4   Tuesday-Friday 12:00 PM-5:00 PM and Saturday-S...   June-October
# ..                                                ...            ...
# 87                              Daily 8:00 AM-4:00 PM   June-October
# 88                          Wednesday 3:00 PM-6:30 PM   June-October
# 89                           Thursday 3:00 PM-6:30 PM  June-November
# 90                             Friday 2:30 PM-3:30 PM     Year Round
# 91                            Tuesday 3:00 PM-4:00 PM     Year Round
#
#                               Affiliations
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 87                                     NaN
# 88                                     NaN
# 89               Just Harvest Fresh Access
# 90  Greater Pittsburgh Community Food Bank
# 91  Greater Pittsburgh Community Food Bank
#
# [92 rows x 11 columns]

# %%
# Assign some columns to schema fields
df['name'] = df['Name']
df['address'] = df['Street_Address']
df['city'] = df['City']
df['state'] = df['State']
df['zip_code'] = df['Zip']
df['latitude'] = df['Latitude']
df['longitude'] = df['Longitude']
df['location_description'] = df['Additional_Directions']

# Set some fields directly
df['source_org'] = 'Allegheny County Health Department'
df['source_file'] = os.path.basename(in_path)
df['type'] = "farmer's market"
df['county'] = 'Allegheny'
df['latlng_source'] = df['source_org']
df['SNAP'] = 1 # because of food_bucks, see below
df['WIC'] = 1
df['FMNP'] = 1
df['fresh_produce'] = 1
df['food_bucks'] = 1 # per Cat email - but do all FMNP farmer's markets participate in Food Bucks??
df['free_distribution'] = 0
df['data_issues'] = '' # start with blank field, to populate later

# Calculate date_from and date_to from Season field
df['Season'] = df['Season'].str.strip(' ') # clean off leading/trailing spaces
df['Season'] = df['Season'].str.split('-')
df['date_from'] = df['Season'].apply(lambda x: try_except(string_to_start_date, x, 0))
df['date_to'] = df['Season'].apply(lambda x: try_except(string_to_end_date, x, -1))

# Someday we will handle opening days/times robustly. For now I will append them to location_description :P
df.loc[df['location_description'].notna(), 'location_description'] = df['location_description'] + '; ' + df['Day_Time']
df.loc[df['location_description'].isna(), 'location_description'] = df['Day_Time']

# Reorder and add any missing columns
df = df.reindex(columns = final_cols)

# Identify which columns we have handled
handled_cols = df.columns[~df.isna().all()] # i.e. columns that aren't all NA

# Detect and document missingness in handled columns
for col in handled_cols:
    df.loc[df[col].isna(), 'data_issues'] += '{} missing;'.format(col)

# Detect some specific data issues 
df.loc[((df['latitude'] == 0) & (df['longitude'] == 0)), 'data_issues'] += 'latlng is (0,0);'

# Write out to CSV
df.to_csv(out_path, index = False)

df
# Out:
#     id                          source_org  \
# 0  NaN  Allegheny County Health Department
# 1  NaN  Allegheny County Health Department
# 2  NaN  Allegheny County Health Department
# 3  NaN  Allegheny County Health Department
# 4  NaN  Allegheny County Health Department
# ..  ..                                 ...
# 87 NaN  Allegheny County Health Department
# 88 NaN  Allegheny County Health Department
# 89 NaN  Allegheny County Health Department
# 90 NaN  Allegheny County Health Department
# 91 NaN  Allegheny County Health Department
#
#                                           source_file  original_id  \
# 0   Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 1   Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 2   Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 3   Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 4   Allegheny_County_Farmers_Markets_Locations_201...          NaN
# ..                                                ...          ...
# 87  Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 88  Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 89  Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 90  Allegheny_County_Farmers_Markets_Locations_201...          NaN
# 91  Allegheny_County_Farmers_Markets_Locations_201...          NaN
#
#                type                              name  \
# 0   farmer's market          Ambridge Farmer's Market
# 1   farmer's market             Aspinwall Flea Market
# 2   farmer's market  Bachman's Greenhouse and Nursery
# 3   farmer's market  Bachman's Greenhouse and Nursery
# 4   farmer's market             Beccari's Farm Market
# ..              ...                               ...
# 87  farmer's market                     Wexford Farms
# 88  farmer's market  Wilkins Township Farmer's Market
# 89  farmer's market       Wilkinsburg Farmer's Market
# 90  farmer's market           Wilmerding Green Grocer
# 91  farmer's market            Woods Run Green Grocer
#
#                       address             city state  zip_code  ...  \
# 0               624 Park Road         Ambridge    PA     15003  ...
# 1       217 Commerical Avenue        Aspinwall    PA     15215  ...
# 2          2905 Freeport Road  Natrona Heights    PA     15065  ...
# 3   Route 908 & Ekastown Road  Natrona Heights    PA     15065  ...
# 4         5095 Thoms Run Road          Oakdale    PA     15071  ...
# ..                        ...              ...   ...       ...  ...
# 87        550 Warrendale Road          Wexford    PA     15090  ...
# 88  333 Penn Center Boulevard       Pittsburgh    PA     15235  ...
# 89            225 Penn Avenue       Pittsburgh    PA     15221  ...
# 90        314 Commerce Street       Wilmerding    PA     15148  ...
# 91      1201 Woods Run Avenue       Pittsburgh    PA     15212  ...
#
#     date_from      date_to  SNAP  WIC  FMNP  fresh_produce food_bucks  \
# 0      June 1  November 30     1    1     1              1          1
# 1      June 1  November 30     1    1     1              1          1
# 2      June 1   October 31     1    1     1              1          1
# 3      July 1   October 31     1    1     1              1          1
# 4      June 1   October 31     1    1     1              1          1
# ..        ...          ...   ...  ...   ...            ...        ...
# 87     June 1   October 31     1    1     1              1          1
# 88     June 1   October 31     1    1     1              1          1
# 89     June 1  November 30     1    1     1              1          1
# 90  January 1  December 31     1    1     1              1          1
# 91  January 1  December 31     1    1     1              1          1
#
#    free_distribution open_to_spec_group  data_issues
# 0                  0                NaN
# 1                  0                NaN
# 2                  0                NaN
# 3                  0                NaN
# 4                  0                NaN
# ..               ...                ...          ...
# 87                 0                NaN
# 88                 0                NaN
# 89                 0                NaN
# 90                 0                NaN
# 91                 0                NaN
#
# [92 rows x 27 columns]
