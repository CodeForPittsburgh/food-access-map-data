# %% [markdown]
# # Allegheny County Farmers' Markets ingestion script prototype
#
# This notebook is intended to prototype code snippets for an ingestion script aimed at "Allegheny_County_Farmers_Markets_Locations_2019.csv".
#
# Note that I (Drew) found an updated input file here: https://data.wprdc.org/dataset/allegheny-county-farmers-markets-locations/resource/77f53ea5-9a40-4047-8235-8ca8a2712f16
#
# Dependencies:
# * pandas
# * os

# %%
import pandas as pd
import os

# %%
in_path = '../food-data/PFPC_data_files/Allegheny_County_Farmers_Markets_Locations_2019.csv'
out_path = '../food-data/cleaned/allegheny_county_farmers_markets.csv'

final_cols = ['id', 'source_org', 'source_file', 'original_id', 'type', 'name', 'address', 'city', 
              'state', 'zip_code', 'county', 'location_description', 'phone', 'url', 'latitude', 
              'longitude', 'latlng_source', 'date_from', 'date_to', 'SNAP', 'WIC', 'FMNP', 
              'fresh_produce', 'food_bucks', 'free_distribution', 'open_to_spec_group', 'data_issues']

# %%
df = pd.read_csv(in_path)
df
# Out:
#                                 Name             Street_Address  \
# 0           Ambridge Farmer's Market              624 Park Road
# 1              Aspinwall Flea Market      217 Commerical Avenue
# 2   Bachman's Greenhouse and Nursery         2905 Freeport Road
# 3   Bachman's Greenhouse and Nursery  Route 908 & Ekastown Road
# 4              Beccari's Farm Market        5095 Thoms Run Road
# ..                               ...                        ...
# 87                     Wexford Farms        550 Warrendale Road
# 88  Wilkins Township Farmer's Market  333 Penn Center Boulevard
# 89       Wilkinsburg Farmer's Market            225 Penn Avenue
# 90           Wilmerding Green Grocer        314 Commerce Street
# 91            Woods Run Green Grocer      1201 Woods Run Avenue
#
#                City State    Zip   Latitude  Longitude  \
# 0          Ambridge    PA  15003  40.586729 -80.229576
# 1         Aspinwall    PA  15215  40.490575 -79.904305
# 2   Natrona Heights    PA  15065  40.640015 -79.711384
# 3   Natrona Heights    PA  15065  40.667206 -79.730284
# 4           Oakdale    PA  15071  40.373965 -80.133129
# ..              ...   ...    ...        ...        ...
# 87          Wexford    PA  15090  40.647630 -80.100129
# 88       Pittsburgh    PA  15235  40.427682 -79.811636
# 89       Pittsburgh    PA  15221  40.446769 -79.891807
# 90       Wilmerding    PA  15148  40.392927 -79.807721
# 91       Pittsburgh    PA  15212  40.476243 -80.030199
#
#                              Additional_Directions  \
# 0   St. Mary's Church parking lot, near Do It Best
# 1                            Municipal parking lot
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 87                                             NaN
# 88                            Route 22 Penn Center
# 89                  Life Care Hospital parking lot
# 90                           Wilmerding Apartments
# 91                               Woods Run Library
#
#                                              Day_Time         Season  \
# 0                            Thursday 4:00 PM-7:00 PM  June-November
# 1                              Sunday 7:00 AM-1:00 PM  June-November
# 2                               Daily 8:00 AM-7:00 PM   June-October
# 3                              Daily 10:00 AM-6:00 PM   July-October
# 4   Tuesday-Friday 12:00 PM-5:00 PM and Saturday-S...   June-October
# ..                                                ...            ...
# 87                              Daily 8:00 AM-4:00 PM   June-October
# 88                          Wednesday 3:00 PM-6:30 PM   June-October
# 89                           Thursday 3:00 PM-6:30 PM  June-November
# 90                             Friday 2:30 PM-3:30 PM     Year Round
# 91                            Tuesday 3:00 PM-4:00 PM     Year Round
#
#                               Affiliations
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 87                                     NaN
# 88                                     NaN
# 89               Just Harvest Fresh Access
# 90  Greater Pittsburgh Community Food Bank
# 91  Greater Pittsburgh Community Food Bank
#
# [92 rows x 11 columns]

# %%
# Drop that one empty row at the end
df = df[df['AgencyRef'].notna()]

# Keep only active sites
df = df[df['Food Bank - Inactive In Inventory System'] == 0] # what about all the blanks?

# Assign some columns to schema fields
df['original_id'] = df['AgencyRef']
df['name'] = df['AgencyName']
df['city'] = df['City']
df['state'] = df['State']
df['zip_code'] = df['Zip']
df['county'] = df['County']
df['latitude'] = df['Google Lat']
df['longitude'] = df['Google Long']

# Set some fields directly
df['source_org'] = 'Greater Pittsburgh Community Food Bank'
df['source_file'] = os.path.basename(in_path)
df['type'] = 'food bank site'
df['latlng_source'] = df['source_org']
df['free_distribution'] = 1
df['data_issues'] = '' # start with blank field, to populate later

# Set the fresh_produce flag
df['GroupTypes'] = df['GroupTypeOne'] + df['GroupTypeTwo'] + df['GroupTypeThree']
df['fresh_produce'] = 0
df.loc[df['GroupTypes'].str.contains('Grocery') | df['GroupTypes'].str.contains('Fresh Market'), 'fresh_produce'] = 1

# Clean up and concatenate address fields
df['Addr1'] = df['Addr1'].str.replace('  ', ' ').str.strip(' ')
df['Addr2'] = df['Addr2'].str.replace('  ', ' ').str.strip(' ')
df.loc[df['Addr2'].notna(), 'address'] = df['Addr1'] + ', ' + df['Addr2']
df.loc[df['Addr2'].isna(), 'address'] = df['Addr1']

# Reorder and add any missing columns
df = df.reindex(columns = final_cols)

# Identify which columns we have handled
handled_cols = df.columns[~df.isna().all()] # i.e. columns that aren't all NA

# Detect and document missingness in handled columns
for col in handled_cols:
    df.loc[df[col].isna(), 'data_issues'] += '{} missing;'.format(col)

# Detect some specific data issues 
df.loc[((df['latitude'] == 0) & (df['longitude'] == 0)), 'data_issues'] += 'latlng is (0,0);'

# Write out to CSV
df.to_csv(out_path, index = False)

df
# Out:
#      id                              source_org  \
# 0   NaN  Greater Pittsburgh Community Food Bank
# 1   NaN  Greater Pittsburgh Community Food Bank
# 2   NaN  Greater Pittsburgh Community Food Bank
# 3   NaN  Greater Pittsburgh Community Food Bank
# 4   NaN  Greater Pittsburgh Community Food Bank
# ..   ..                                     ...
# 555 NaN  Greater Pittsburgh Community Food Bank
# 556 NaN  Greater Pittsburgh Community Food Bank
# 557 NaN  Greater Pittsburgh Community Food Bank
# 558 NaN  Greater Pittsburgh Community Food Bank
# 559 NaN  Greater Pittsburgh Community Food Bank
#
#                                       source_file original_id            type  \
# 0    2019-10-10 PGH Food Bank Site Addresses.xlsx  PAGI2450-1  food bank site
# 1    2019-10-10 PGH Food Bank Site Addresses.xlsx  PADA2545-1  food bank site
# 2    2019-10-10 PGH Food Bank Site Addresses.xlsx  PADE2513-1  food bank site
# 3    2019-10-10 PGH Food Bank Site Addresses.xlsx  PADO2493-1  food bank site
# 4    2019-10-10 PGH Food Bank Site Addresses.xlsx  PAGH2543-1  food bank site
# ..                                            ...         ...             ...
# 555  2019-10-10 PGH Food Bank Site Addresses.xlsx  PWOM1387-1  food bank site
# 556  2019-10-10 PGH Food Bank Site Addresses.xlsx  PWOM1386-1  food bank site
# 557  2019-10-10 PGH Food Bank Site Addresses.xlsx  PYMC1391-1  food bank site
# 558  2019-10-10 PGH Food Bank Site Addresses.xlsx  PYOR2318-1  food bank site
# 559  2019-10-10 PGH Food Bank Site Addresses.xlsx  PZIO1179-1  food bank site
#
#                                                  name  \
# 0                                      A Giving Heart
# 1                                      Adagio Health
# 2                         Adelphoi Education Millvale
# 3                             Adolecent Medicine UPMC
# 4                                  AGH Federal North
# ..                                                ...
# 555                             Womanspace East, Inc.
# 556  Women's Center and Shelter of Greater Pittsburgh
# 557                               YMCA New Kensington
# 558                                      York Commons
# 559                             Zion Christian Church
#
#                         address            city state zip_code  ... date_from  \
# 0             816 Climax Street      Pittsburgh    PA    15210  ...       NaN
# 1          116 Browns Hill Road        Valencia    PA    16059  ...       NaN
# 2           608 Farragut Street      Pittsburgh    PA    15209  ...       NaN
# 3       4401 Penn Ave., Floor 3      Pittsburgh    PA    15224  ...       NaN
# 4           1307 Federal Street     Pittsburgh     PA    15212  ...       NaN
# ..                          ...             ...   ...      ...  ...       ...
# 555                         NaN             NaN   NaN      NaN  ...       NaN
# 556                         NaN             NaN   NaN      NaN  ...       NaN
# 557  800 Constitution Boulevard  New Kensington    PA    15068  ...       NaN
# 558              4003 Penn Ave.      Pittsburgh    PA    15224  ...       NaN
# 559       2019 Brownsville Road      Pittsburgh    PA    15210  ...       NaN
#
#      date_to  SNAP  WIC FMNP fresh_produce food_bucks  free_distribution  \
# 0        NaN   NaN  NaN  NaN             0        NaN                  1
# 1        NaN   NaN  NaN  NaN             0        NaN                  1
# 2        NaN   NaN  NaN  NaN             0        NaN                  1
# 3        NaN   NaN  NaN  NaN             0        NaN                  1
# 4        NaN   NaN  NaN  NaN             0        NaN                  1
# ..       ...   ...  ...  ...           ...        ...                ...
# 555      NaN   NaN  NaN  NaN             0        NaN                  1
# 556      NaN   NaN  NaN  NaN             0        NaN                  1
# 557      NaN   NaN  NaN  NaN             0        NaN                  1
# 558      NaN   NaN  NaN  NaN             0        NaN                  1
# 559      NaN   NaN  NaN  NaN             1        NaN                  1
#
#      open_to_spec_group                                        data_issues
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...                                                ...
# 555                 NaN  address missing;city missing;state missing;zip...
# 556                 NaN  address missing;city missing;state missing;zip...
# 557                 NaN
# 558                 NaN
# 559                 NaN
#
# [560 rows x 27 columns]
